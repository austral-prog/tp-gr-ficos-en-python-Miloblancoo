# %%
import matplotlib.pyplot as plt

# %%
plt.title("Goles de Messi")
plt.xlabel("goles")
plt.ylabel("año")
plt.grid(True)
plt.legend(['Goles'])
# Set axis limits
plt.xlim(0, 90)
plt.ylim(2018, 2025)
# Add text
plt.plot([1,2,3,4], [1,4,9,16], 'ro-')
